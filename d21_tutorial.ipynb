# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow import keras
from tensorflow.keras import layers

train_dataset = image_dataset_from_directory(
    "cats_vs_dogs_small\\train",
    image_size=(180,180),
    batch_size=32)
validation_dataset = image_dataset_from_directory(
    "cats_vs_dogs_small\\validation",
    image_size=(180,180),
    batch_size=32)
test_dataset = image_dataset_from_directory(
    "cats_vs_dogs_small\\test",
    image_size=(180,180),
    batch_size=32)
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# Found 2000 files belonging to 2 classes.

# %%
for data, label in train_dataset.take(1):
    plt.imshow(data[30].numpy().astype("uint8"))

# %% [raw]
# Above I have displayed an image after it has been converteed to a tensoflow_dataset.
# the train_dataset returns two items a list of 32 images, and their labels.
# .take(N) is a method that insert a break in the loop after Nth batch. For instance in my example .take(1), it will the stop th eloop after the first batch.
