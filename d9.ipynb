# %% [markdown]
# ## A simple logistic regression on MNIST

# %%
from tensorflow.keras.datasets import mnist
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers

(train_images, train_labels), _= mnist.load_data()
train_images = train_images.reshape((60000, 28*28))
train_images = train_images.astype("float32") / 255


model = keras.Sequential([
        #layers.Dense(512, activation="relu"),
        layers.Dense(10, activation="softmax")
    ])
    
model.compile(optimizer="rmsprop",
                 loss="sparse_categorical_crossentropy",
                 metrics=["accuracy"])
history_small_model = model.fit(train_images, train_labels, epochs=20,
         batch_size=128, validation_split=0.2)
# Out:
# Epoch 1/20
# 375/375 [==============================] - 4s 8ms/step - loss: 0.6810 - accuracy: 0.8315 - val_loss: 0.3597 - val_accuracy: 0.9047
# Epoch 2/20
# 375/375 [==============================] - 3s 8ms/step - loss: 0.3518 - accuracy: 0.9037 - val_loss: 0.3087 - val_accuracy: 0.9159
# Epoch 3/20
# 375/375 [==============================] - 3s 8ms/step - loss: 0.3160 - accuracy: 0.9126 - val_loss: 0.2914 - val_accuracy: 0.9180
# Epoch 4/20
# 375/375 [==============================] - 3s 8ms/step - loss: 0.2998 - accuracy: 0.9162 - val_loss: 0.2811 - val_accuracy: 0.9219
# Epoch 5/20
# 375/375 [==============================] - 3s 8ms/step - loss: 0.2896 - accuracy: 0.9192 - val_loss: 0.2749 - val_accuracy: 0.9246
# Epoch 6/20
# 375/375 [==============================] - 3s 8ms/step - loss: 0.2835 - accuracy: 0.9208 - val_loss: 0.2727 - val_accuracy: 0.9243
# Epoch 7/20
# 375/375 [==============================] - 3s 8ms/step - loss: 0.2783 - accuracy: 0.9215 - val_loss: 0.2683 - val_accuracy: 0.9273
# Epoch 8/20
# 375/375 [==============================] - 3s 7ms/step - loss: 0.2743 - accuracy: 0.9229 - val_loss: 0.2664 - val_accuracy: 0.9263
# Epoch 9/20
# 375/375 [==============================] - 3s 7ms/step - loss: 0.2712 - accuracy: 0.9249 - val_loss: 0.2664 - val_accuracy: 0.9282
# Epoch 10/20
# 375/375 [==============================] - 3s 7ms/step - loss: 0.2688 - accuracy: 0.9255 - val_loss: 0.2641 - val_accuracy: 0.9298
# Epoch 11/20
# 375/375 [==============================] - 3s 8ms/step - loss: 0.2665 - accuracy: 0.9261 - val_loss: 0.2633 - val_accuracy: 0.9291
# Epoch 12/20
# 375/375 [==============================] - 3s 8ms/step - loss: 0.2647 - accuracy: 0.9264 - val_loss: 0.2641 - val_accuracy: 0.9280
# Epoch 13/20
# 375/375 [==============================] - 3s 8ms/step - loss: 0.2629 - accuracy: 0.9274 - val_loss: 0.2635 - val_accuracy: 0.9287
# Epoch 14/20
# 375/375 [==============================] - 3s 8ms/step - loss: 0.2615 - accuracy: 0.9283 - val_loss: 0.2623 - val_accuracy: 0.9304
# Epoch 15/20
# 375/375 [==============================] - 3s 8ms/step - loss: 0.2605 - accuracy: 0.9281 - val_loss: 0.2600 - val_accuracy: 0.9298
# Epoch 16/20
# 375/375 [==============================] - 3s 8ms/step - loss: 0.2593 - accuracy: 0.9285 - val_loss: 0.2629 - val_accuracy: 0.9296
# Epoch 17/20
# 375/375 [==============================] - 3s 7ms/step - loss: 0.2584 - accuracy: 0.9293 - val_loss: 0.2614 - val_accuracy: 0.9297
# Epoch 18/20
# 375/375 [==============================] - 3s 7ms/step - loss: 0.2575 - accuracy: 0.9293 - val_loss: 0.2624 - val_accuracy: 0.9308
# Epoch 19/20
# 375/375 [==============================] - 3s 8ms/step - loss: 0.2567 - accuracy: 0.9296 - val_loss: 0.2615 - val_accuracy: 0.9314
# Epoch 20/20
# 375/375 [==============================] - 3s 7ms/step - loss: 0.2560 - accuracy: 0.9300 - val_loss: 0.2596 - val_accuracy: 0.9309

# %%
import matplotlib.pyplot as plt
val_loss = history_small_model.history["val_loss"]
epochs = range(1,21)
plt.plot(epochs, val_loss, "b--", label="validation loss")
plt.title("Effect of insufficient model capacity on validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
