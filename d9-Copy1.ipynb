# %% [markdown]
# ## A simple logistic regression on MNIST

# %%
from tensorflow.keras.datasets import mnist
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers

(train_images, train_labels), _= mnist.load_data()
train_images = train_images.reshape((60000, 28*28))
train_images = train_images.astype("float32") / 255


model = keras.Sequential([
        layers.Dense(96, activation="relu"),
        layers.Dense(96, activation="relu"),
        layers.Dense(10, activation="softmax")
    ])
    
model.compile(optimizer="rmsprop",
                 loss="sparse_categorical_crossentropy",
                 metrics=["accuracy"])
history_small_model = model.fit(train_images, train_labels, epochs=20,
         batch_size=128, validation_split=0.2)
# Out:
# Epoch 1/20
# 375/375 [==============================] - 6s 10ms/step - loss: 0.3634 - accuracy: 0.8980 - val_loss: 0.2030 - val_accuracy: 0.9412
# Epoch 2/20
# 375/375 [==============================] - 3s 9ms/step - loss: 0.1654 - accuracy: 0.9508 - val_loss: 0.1394 - val_accuracy: 0.9593
# Epoch 3/20
# 375/375 [==============================] - 3s 9ms/step - loss: 0.1161 - accuracy: 0.9656 - val_loss: 0.1255 - val_accuracy: 0.9651
# Epoch 4/20
# 375/375 [==============================] - 4s 9ms/step - loss: 0.0883 - accuracy: 0.9735 - val_loss: 0.1051 - val_accuracy: 0.9697
# Epoch 5/20
# 375/375 [==============================] - 3s 8ms/step - loss: 0.0700 - accuracy: 0.9785 - val_loss: 0.1053 - val_accuracy: 0.9706
# Epoch 6/20
# 375/375 [==============================] - 3s 8ms/step - loss: 0.0568 - accuracy: 0.9825 - val_loss: 0.1027 - val_accuracy: 0.9707
# Epoch 7/20
# 375/375 [==============================] - 3s 8ms/step - loss: 0.0481 - accuracy: 0.9850 - val_loss: 0.1056 - val_accuracy: 0.9712
# Epoch 8/20
# 375/375 [==============================] - 3s 8ms/step - loss: 0.0395 - accuracy: 0.9877 - val_loss: 0.0970 - val_accuracy: 0.9740
# Epoch 9/20
# 375/375 [==============================] - 3s 8ms/step - loss: 0.0343 - accuracy: 0.9893 - val_loss: 0.1003 - val_accuracy: 0.9741
# Epoch 10/20
# 375/375 [==============================] - 3s 8ms/step - loss: 0.0284 - accuracy: 0.9913 - val_loss: 0.1104 - val_accuracy: 0.9735
# Epoch 11/20
# 375/375 [==============================] - 3s 8ms/step - loss: 0.0244 - accuracy: 0.9919 - val_loss: 0.1064 - val_accuracy: 0.9739
# Epoch 12/20
# 375/375 [==============================] - 3s 8ms/step - loss: 0.0204 - accuracy: 0.9939 - val_loss: 0.1062 - val_accuracy: 0.9758
# Epoch 13/20
# 375/375 [==============================] - 3s 8ms/step - loss: 0.0169 - accuracy: 0.9949 - val_loss: 0.1096 - val_accuracy: 0.9744
# Epoch 14/20
# 375/375 [==============================] - 3s 8ms/step - loss: 0.0156 - accuracy: 0.9955 - val_loss: 0.1095 - val_accuracy: 0.9761
# Epoch 15/20
# 375/375 [==============================] - 3s 8ms/step - loss: 0.0126 - accuracy: 0.9960 - val_loss: 0.1216 - val_accuracy: 0.9752
# Epoch 16/20
# 375/375 [==============================] - 3s 8ms/step - loss: 0.0105 - accuracy: 0.9967 - val_loss: 0.1273 - val_accuracy: 0.9753
# Epoch 17/20
# 375/375 [==============================] - 3s 8ms/step - loss: 0.0101 - accuracy: 0.9967 - val_loss: 0.1426 - val_accuracy: 0.9728
# Epoch 18/20
# 375/375 [==============================] - 3s 8ms/step - loss: 0.0079 - accuracy: 0.9975 - val_loss: 0.1327 - val_accuracy: 0.9756
# Epoch 19/20
# 375/375 [==============================] - 3s 8ms/step - loss: 0.0071 - accuracy: 0.9979 - val_loss: 0.1411 - val_accuracy: 0.9742
# Epoch 20/20
# 375/375 [==============================] - 3s 8ms/step - loss: 0.0067 - accuracy: 0.9978 - val_loss: 0.1400 - val_accuracy: 0.9758

# %%
import matplotlib.pyplot as plt
val_loss = history_small_model.history["val_loss"]
epochs = range(1,21)
plt.plot(epochs, val_loss, "b--", label="validation loss")
plt.title("Effect of insufficient model capacity on validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
